# %%
import tensorflow as tf

# %%
data_dir = "/kaggle/input/digit-dataset/digit_dataset2"

# %%
batch_size = 32
image_size = (256, 256)
seed = 123

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    labels='inferred',
    label_mode='int',
    color_mode='rgb',
    batch_size=batch_size,
    image_size=image_size,
    shuffle=True,
    seed=seed,
    validation_split=0.2,  # Reserve 20% for validation and test
    subset="training",
)
# Out:
# Found 2000 files belonging to 10 classes.
# Using 1600 files for training.

# %%
validation_test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    labels='inferred',
    label_mode='int',
    color_mode='rgb',
    batch_size=batch_size,
    image_size=image_size,
    shuffle=True,
    seed=seed,
    validation_split=0.2,
    subset="validation",
)
# Out:
# Found 2000 files belonging to 10 classes.
# Using 400 files for validation.

# %%
val_size = len(validation_test_ds) // 2 
val_ds = validation_test_ds.take(val_size)  
test_ds = validation_test_ds.skip(val_size)

# %%
test_ds
# Out:
# <_SkipDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
normalization_layer = tf.keras.layers.Rescaling(1.0 / 255)

# %%
train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))
test_ds = test_ds.map(lambda x, y: (normalization_layer(x), y))

# %%
# Prefetch to improve performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
from tensorflow.keras import layers, models

# %%
model = models.Sequential()

# %%
model.add(layers.InputLayer(input_shape=(256, 256, 3)))
model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(38, activation='softmax'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 256, 256, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 128, 128, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 128, 128, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 64, 64, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 131072)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │      67,109,376 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 38)                  │           9,766 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 67,343,718 (256.90 MB)
#  Trainable params: 67,343,718 (256.90 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    verbose=1,
)
# Out:
# Epoch 1/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 127ms/step - accuracy: 0.1274 - loss: 3.4616 - val_accuracy: 0.5052 - val_loss: 1.7525
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.4145 - loss: 1.7802 - val_accuracy: 0.7292 - val_loss: 0.8684
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.6670 - loss: 0.9568 - val_accuracy: 0.8594 - val_loss: 0.4903
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.7802 - loss: 0.6343 - val_accuracy: 0.8646 - val_loss: 0.3543
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.8618 - loss: 0.3889 - val_accuracy: 0.9167 - val_loss: 0.2012
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.8969 - loss: 0.2853 - val_accuracy: 0.9375 - val_loss: 0.1993
# Epoch 7/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9338 - loss: 0.2019 - val_accuracy: 0.9688 - val_loss: 0.1315
# Epoch 8/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9308 - loss: 0.1783 - val_accuracy: 0.9792 - val_loss: 0.0591
# Epoch 9/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9708 - loss: 0.0838 - val_accuracy: 0.9792 - val_loss: 0.0764
# Epoch 10/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9723 - loss: 0.0872 - val_accuracy: 0.9844 - val_loss: 0.0502
# Epoch 11/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9745 - loss: 0.0751 - val_accuracy: 0.9688 - val_loss: 0.0890
# Epoch 12/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9633 - loss: 0.0945 - val_accuracy: 0.9740 - val_loss: 0.0782
# Epoch 13/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9739 - loss: 0.0813 - val_accuracy: 0.9792 - val_loss: 0.0679
# Epoch 14/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9772 - loss: 0.0676 - val_accuracy: 0.9896 - val_loss: 0.0373
# Epoch 15/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9740 - loss: 0.0835 - val_accuracy: 0.9792 - val_loss: 0.0856
# Epoch 16/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9715 - loss: 0.0904 - val_accuracy: 0.9688 - val_loss: 0.1245
# Epoch 17/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9751 - loss: 0.0756 - val_accuracy: 0.9688 - val_loss: 0.0916
# Epoch 18/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9840 - loss: 0.0703 - val_accuracy: 0.9792 - val_loss: 0.0717
# Epoch 19/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9798 - loss: 0.0607 - val_accuracy: 0.9688 - val_loss: 0.1092
# Epoch 20/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9827 - loss: 0.0515 - val_accuracy: 0.9844 - val_loss: 0.0435
# Epoch 21/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9796 - loss: 0.0657 - val_accuracy: 0.9896 - val_loss: 0.0369
# Epoch 22/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9842 - loss: 0.0480 - val_accuracy: 0.9844 - val_loss: 0.0564
# Epoch 23/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9902 - loss: 0.0327 - val_accuracy: 0.9844 - val_loss: 0.0434
# Epoch 24/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9946 - loss: 0.0197 - val_accuracy: 0.9688 - val_loss: 0.0582
# Epoch 25/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9889 - loss: 0.0497 - val_accuracy: 0.9792 - val_loss: 0.0697
# Epoch 26/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9891 - loss: 0.0342 - val_accuracy: 0.9792 - val_loss: 0.0968
# Epoch 27/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9941 - loss: 0.0164 - val_accuracy: 0.9844 - val_loss: 0.0866
# Epoch 28/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9909 - loss: 0.0216 - val_accuracy: 0.9844 - val_loss: 0.1329
# Epoch 29/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9900 - loss: 0.0300 - val_accuracy: 0.9844 - val_loss: 0.0907
# Epoch 30/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9895 - loss: 0.0302 - val_accuracy: 0.9792 - val_loss: 0.0824
# Epoch 31/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9923 - loss: 0.0219 - val_accuracy: 0.9635 - val_loss: 0.1308
# Epoch 32/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9805 - loss: 0.0452 - val_accuracy: 0.9688 - val_loss: 0.1285
# Epoch 33/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9956 - loss: 0.0168 - val_accuracy: 0.9896 - val_loss: 0.0480
# Epoch 34/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9942 - loss: 0.0135 - val_accuracy: 0.9740 - val_loss: 0.0885
# Epoch 35/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9961 - loss: 0.0138 - val_accuracy: 0.9896 - val_loss: 0.0451
# Epoch 36/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9927 - loss: 0.0188 - val_accuracy: 0.9896 - val_loss: 0.0404
# Epoch 37/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9914 - loss: 0.0415 - val_accuracy: 0.9844 - val_loss: 0.0516
# Epoch 38/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9955 - loss: 0.0228 - val_accuracy: 0.9740 - val_loss: 0.1047
# Epoch 39/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9956 - loss: 0.0133 - val_accuracy: 0.9740 - val_loss: 0.1325
# Epoch 40/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9877 - loss: 0.0320 - val_accuracy: 0.9635 - val_loss: 0.0902
# Epoch 41/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9942 - loss: 0.0126 - val_accuracy: 0.9740 - val_loss: 0.0566
# Epoch 42/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9912 - loss: 0.0342 - val_accuracy: 0.9740 - val_loss: 0.0645
# Epoch 43/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9971 - loss: 0.0119 - val_accuracy: 0.9635 - val_loss: 0.1359
# Epoch 44/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9966 - loss: 0.0112 - val_accuracy: 0.9844 - val_loss: 0.0389
# Epoch 45/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9883 - loss: 0.0460 - val_accuracy: 0.9635 - val_loss: 0.1289
# Epoch 46/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9991 - loss: 0.0056 - val_accuracy: 0.9792 - val_loss: 0.0662
# Epoch 47/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9964 - loss: 0.0094 - val_accuracy: 0.9792 - val_loss: 0.0713
# Epoch 48/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9959 - loss: 0.0157 - val_accuracy: 0.9583 - val_loss: 0.2260
# Epoch 49/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9941 - loss: 0.0256 - val_accuracy: 0.9531 - val_loss: 0.1833
# Epoch 50/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9922 - loss: 0.0204 - val_accuracy: 0.9844 - val_loss: 0.0445

# %%
import matplotlib.pyplot as plt

# %%
#  Plot Training and Validation Accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

#  Plot Training and Validation Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
from tensorflow.keras.utils import load_img, img_to_array

# %%
image_path = "/kaggle/input/digit-dataset/digit_dataset2/0/digit_0_121.png"

# %%
image = load_img(image_path)

# Display the image
plt.imshow(image)
plt.axis('on')
plt.show()

# %%
image = load_img(image_path, target_size=(256, 256))  
image_array = img_to_array(image)  
image_array = image_array / 255.0 
image_array = np.expand_dims(image_array, axis=0)

# %%
predictions = model.predict(image_array)
predicted_label = np.argmax(predictions[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 857ms/step

# %%
temp_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    labels='inferred',
    label_mode='int',
    color_mode='rgb',
    batch_size=batch_size,
    image_size=image_size,
    shuffle=False
)
# Out:
# Found 2000 files belonging to 10 classes.

# %%
class_names = temp_ds.class_names

# %%
predicted_class_name = class_names[predicted_label]

# %%
predicted_class_name
# Out:
# '0'

# %%
plt.figure(figsize=(15, 15))

for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        
        img = (images[i].numpy() * 255).astype("uint8")
        plt.imshow(img)

        prediction = model.predict(images[i:i+1])
        predicted_class = class_names[prediction.argmax()]
        confidence = 100 * tf.reduce_max(tf.nn.softmax(prediction))

        actual_class = class_names[labels[i].numpy()]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence:.2f}%")
        
        plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
model.save('/kaggle/working/digits_predict_model.h5')
